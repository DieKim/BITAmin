# %% [markdown]
# ### 1. 발표자료 27p에 나와있었던 X의 변수변형 과정을 참고해 Y의 변수 변형 세가지 경우를 직접 수행해보세요.
#
# ### ( $\hat{β_0},  \hat{β_1}$ 을 구해주시면 됩니다 )

# %% [markdown]
# ### (답안)

# %% [markdown]
# 악 왤케 부담스럽게 크죠...?
#
#
# ![KakaoTalk_20210523_205616613.jpg](attachment:KakaoTalk_20210523_205616613.jpg)

# %% [markdown]
# ### 2. $Y = β_0 + β_1 x_i + ε$모델이 데이터에 적합할 때, $Y$ 와 $\hat{Y}$ 의 산점도, $Y$ 와 $X$의 산점도는 어떤 차이, 또는 관계를 보이는지 설명하세요
#
# ### (말로 간단히 설명하셔도 좋고, 직접 산점도를 코드로 만들어 보여주셔도 좋습니다)

# %% [markdown]
# ### (답안)
#
# * 단순선형회귀에서 (X,Y)의 산점도는 실제 데이터의 분포로, 선형 관계(직선 형태)를 띄고 있을 때 효과적으로 회귀분석이 가능합니다.
# * 이때 Y가 실제 관측값이라면 Y_hat은 예측값(추정값)으로 산점도로 나타내면 데이터를 가장 잘 나타내는 회귀선을 의미합니다.

# %% [markdown]
# ![KakaoTalk_20210523_204609372.jpg](attachment:KakaoTalk_20210523_204609372.jpg)

# %% [markdown]
# ### 3. 변수의 개수가 많아 다중공선성이 우려되는 상황에서 정규화 방법을 쓰고자 합니다.
#
# ### 이때 많은 변수들 중 몇 개의 변수만이 종속변수에 유의미한 영향을 줄 것으로 예상된다면 릿지와 라쏘 중 어떤 방법이 더 도움이 될까요?

# %% [markdown]
# ### (답안)
#
# * Lasso
# * Ridge와 달리 Lasso는 변수 선택이 가능하므로 유의미한 영향을 주는 특정 몇 개의 변수를 고르는 작업이 가능하다.

# %% [markdown]
# ### 4. 다음의 코드를 실행시켜 보고 결과에 대해 설명해 주세요!
#
# ### (mglearn 설치 필요 : pip install mglearn)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import mglearn
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X, y = mglearn.datasets.load_extended_boston()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)
mglearn.plots.plot_ridge_n_samples()

# %% [markdown]
# ### (답안)

# %% [markdown]
# * 선형회귀와 릿지를 각각 train/test set에 적용한 후 score(결정계수)를 확인한 그래프이다.
# * (당연하게도) 모두 test set 보다는 train set에서 더 안정적인 점수를 보인다.
# * 릿지에는 규제가 적용되므로 train set에서는 선형회귀가 더 높은 점수를 보인다.
# * 단, test set과 같이 적은 양의 데이터에서는 릿지가 더 높은 점수를 보인다.
# * 데이터셋 크기가 커질수록 규제항이 덜 중요해져서 두 회귀의 성능이 비슷해진다.
# * 선형회귀의 train set 성능이 점점 감소하는 것을 보아 과적합이 일어난다고 예상할 수 있다.
# * 또한 선형회귀의 경우 test set이 400개보다 적을 때는 거의 학습하지 못하는 듯하다.
